# %%
# the following assumptions was made:
    # The airports.csv file contains a complete list of all airports in the United States.
    # The weather.csv file contains accurate weather data for all airports in the United States.
# I did not make any changes to the data.



import pandas as pd
airports = pd.read_csv("C:\\Users\\abdul\\Dropbox\\PC\\Desktop\\airports.csv")

# %%
airports.head()
# Out:
#    faa                           name        lat        lon   alt  tz dst  \
# 0  04G              Lansdowne Airport  41.130472 -80.619583  1044  -5   A
# 1  06A  Moton Field Municipal Airport  32.460572 -85.680028   264  -6   A
# 2  06C            Schaumburg Regional  41.989341 -88.101243   801  -6   A
# 3  06N                Randall Airport  41.431912 -74.391561   523  -5   A
# 4  09J          Jekyll Island Airport  31.074472 -81.427778    11  -5   A
#
#               tzone
# 0  America/New_York
# 1   America/Chicago
# 2   America/Chicago
# 3  America/New_York
# 4  America/New_York

# %%
import pandas as pd
airports = pd.read_csv("C:\\Users\\abdul\\Dropbox\\PC\\Desktop\\airports.csv")
airports.head()
airports.sort_values("lat", ascending=False).head(5)

# the northernmost airport is Dillant Hopkins Airport since it has the highest latitude.
# Out:
#      faa                                        name        lat         lon  \
# 417  EEN                     Dillant Hopkins Airport  72.270833   42.898333
# 230  BRW                  Wiley Post Will Rogers Mem  71.285446 -156.766003
# 110  AIN                          Wainwright Airport  70.638056 -159.994722
# 708  K03                               Wainwright As  70.613378 -159.860350
# 152  ATK  Atqasuk Edward Burnell Sr Memorial Airport  70.467300 -157.436000
#
#      alt  tz dst              tzone
# 417  149  -5   A                NaN
# 230   44  -9   A  America/Anchorage
# 110   41  -9   A  America/Anchorage
# 708   35  -9   A  America/Anchorage
# 152   96  -9   A  America/Anchorage

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\abdul\\Dropbox\\PC\\Desktop\\airports.csv")
northeast_airports = df[(df['lat'] > 44) & (df['lat'] <= 50) & (df['lon'] >= -75) & (df['lon'] <= -65)]
northeast_airports.sort_values('lat', ascending=False).head(5)

# The easternmost airport is Northern Aroostook Regional Airport, faa name WFK.
# making lat range in 44 to 50 and a lon in -65 to -75 would show the airports on the far eastern corridor
# Out:
#       faa                                 name        lat        lon  alt  tz  \
# 1398  WFK  Northern Aroostook Regional Airport  47.285556 -68.312778  988  -5
# 259   CAR                         Caribou Muni  46.871500 -68.017917  626  -5
# 1101  PQI  Northern Maine Rgnl At Presque Isle  46.688958 -68.044797  534  -5
# 624   HUL                         Houlton Intl  46.123083 -67.792056  489  -5
# 894   MLT                     Millinocket Muni  45.647836 -68.685561  408  -5
#
#      dst             tzone
# 1398   A  America/New_York
# 259    A  America/New_York
# 1101   A  America/New_York
# 624    A  America/New_York
# 894    A  America/New_York

# %%
# since EWR had unrealistic wind speed, LGA had the windiest weatherwith,23.02 mph.

speed = pd.read_csv("C:\\Users\\abdul\\Dropbox\\PC\\Desktop\\weather.csv")
speed.head()
speed[(speed["month"]==2) & (speed["day"]==12) & (speed["year"]==2013)].sort_values("wind_speed",ascending=False)
# Out:
#       origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 1009     EWR  2013      2   12     3  39.02  26.96  61.63     260.0
# 18417    LGA  2013      2   12     2  42.98  26.06  50.94     290.0
# 1018     EWR  2013      2   12    12  44.06  26.06  48.87     270.0
# 18428    LGA  2013      2   12    13  44.06  23.00  43.02     300.0
# 18429    LGA  2013      2   12    14  44.06  23.00  43.02     300.0
# ...      ...   ...    ...  ...   ...    ...    ...    ...       ...
# 1006     EWR  2013      2   12     0  39.92  39.02  96.55     240.0
# 1027     EWR  2013      2   12    21  35.96  24.08  61.67     300.0
# 18415    LGA  2013      2   12     0  42.08  37.40  86.89       NaN
# 9709     JFK  2013      2   12     0  42.08  37.04  82.17     280.0
# 1029     EWR  2013      2   12    23  35.96  23.00  58.94     250.0
#
#        wind_speed  wind_gust  precip  pressure  visib             time_hour
# ...
